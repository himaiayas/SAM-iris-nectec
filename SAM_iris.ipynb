# %% [markdown]
# # Setting up

# %% [markdown]
# **Upload** images folder from [Drive](https://drive.google.com/drive/folders/1k71bUZh5biqd04zzTQpm97fDBEDxrxRa)
#
# Using sample iris image (still waiting for account activation to download `CASIA_iris`)

# %%
# %pip install -q 'git+https://github.com/facebookresearch/segment-anything.git'
# %pip install supervision
# %pip install jupyter_bbox_widget
# Out:
# ERROR: Invalid requirement: "'git+https://github.com/facebookresearch/segment-anything.git'"
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: supervision in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (0.20.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\nitro\appdata\roaming\python\python311\site-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from supervision) (3.7.2)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from supervision) (1.23.5)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from supervision) (4.9.0.80)
# Requirement already satisfied: pillow>=9.4 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from supervision) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from supervision) (6.0.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from supervision) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.6.0->supervision) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.6.0->supervision) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.6.0->supervision) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.6.0->supervision) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.6.0->supervision) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.6.0->supervision) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.6.0->supervision) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting jupyter_bbox_widget
#   Obtaining dependency information for jupyter_bbox_widget from https://files.pythonhosted.org/packages/96/0f/9e1f50a37d0776dede4d260584369bf5e1f956670a796e50c9b565f32de7/jupyter_bbox_widget-0.5.0-py2.py3-none-any.whl.metadata
#   Downloading jupyter_bbox_widget-0.5.0-py2.py3-none-any.whl.metadata (8.8 kB)
# Collecting ipywidgets>=7.0.0 (from jupyter_bbox_widget)
#   Obtaining dependency information for ipywidgets>=7.0.0 from https://files.pythonhosted.org/packages/70/1a/7edeedb1c089d63ccd8bd5c0612334774e90cf9337de9fe6c82d90081791/ipywidgets-8.1.2-py3-none-any.whl.metadata
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\nitro\appdata\roaming\python\python311\site-packages (from ipywidgets>=7.0.0->jupyter_bbox_widget) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=7.0.0->jupyter_bbox_widget) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=7.0.0->jupyter_bbox_widget) (5.9.0)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets>=7.0.0->jupyter_bbox_widget)
#   Obtaining dependency information for widgetsnbextension~=4.0.10 from https://files.pythonhosted.org/packages/99/bc/82a8c3985209ca7c0a61b383c80e015fd92e74f8ba0ec1af98f9d6ca8dce/widgetsnbextension-4.0.10-py3-none-any.whl.metadata
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets>=7.0.0->jupyter_bbox_widget)
#   Obtaining dependency information for jupyterlab-widgets~=3.0.10 from https://files.pythonhosted.org/packages/24/da/db1cb0387a7e4086780aff137987ee924e953d7f91b2a870f994b9b1eeb8/jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: backcall in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (0.2.0)
# Requirement already satisfied: decorator in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (0.6.2)
# Requirement already satisfied: colorama in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (0.2.2)
# Requirement already satisfied: six in c:\users\nitro\appdata\local\programs\python\python311\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->jupyter_bbox_widget) (1.16.0)
# Downloading jupyter_bbox_widget-0.5.0-py2.py3-none-any.whl (367 kB)
#    ---------------------------------------- 0.0/367.8 kB ? eta -:--:--
#    ------------------------------ --------- 276.5/367.8 kB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 367.8/367.8 kB 7.6 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    ---------------------------------------- 139.4/139.4 kB 8.6 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.0 kB ? eta -:--:--
#    --------------------------------------- 215.0/215.0 kB 13.7 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------ --------------------------------- 0.4/2.3 MB 11.2 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.3 MB 9.6 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.3 MB 10.1 MB/s eta 0:00:01
#    ------------------------- -------------- 1.5/2.3 MB 10.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 9.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.2/2.3 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 9.8 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets, jupyter_bbox_widget
# Successfully installed ipywidgets-8.1.2 jupyter_bbox_widget-0.5.0 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
HOME_PATH = os.getcwd()

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

MODEL_TYPE = "vit_h"
CHECKPOINT_PATH = os.path.join(HOME_PATH, "weights", "sam_iris.pt") #sam_iris.pt
DEVICE = "cpu"  # "cpu"/"cuda"

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE).eval()

# %%
# Using Iris weight
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor
import torch

MODEL_TYPE = "vit_h"
CHECKPOINT_PATH = os.path.join(HOME_PATH, "weights", "sam_vit_h_4b8939.pth") #sam_iris.pt
DEVICE = "cuda:2" if torch.cuda.is_available() else "cpu"

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)

# %% [markdown]
# # Segmentation

# %%
mask_predictor = SamPredictor(sam)
mask_generator = SamAutomaticMaskGenerator(sam)

# %%
import os
import base64
import cv2

#image = os.path.join(HOME_PATH, "images", "iris.jpg")
image = os.path.join(HOME_PATH, "images", "CASIA-Iris-Thousand","116","L","S5116L01.jpg")

pathList = randIrisPath("CASIA-Iris-Thousand",1)
for path in pathList:print(path)
image = pathList[0]

img = cv2.imread(image)


def encode_image(filepath):
    with open(filepath, 'rb') as f:
        image_bytes = f.read()
    encoded = str(base64.b64encode(image_bytes), 'utf-8')
    return "data:image/jpg;base64,"+encoded


print(encode_image(image))
print(img.shape)
# Out:
# d:\mc\py\nectecproj\SAM-iris-nectec/images/CASIA-Iris-Thousand/500/L/S5500L00.jpg
# data:image/jpg;base64,...
# (480, 640, 3)

# %%
masks = mask_generator.generate(img)

# %%
import supervision as sv
mask_annotator = sv.MaskAnnotator(color_lookup=sv.ColorLookup.INDEX)

detection = sv.Detections.from_sam(sam_result=masks)

images = [img]
for i in range(len(detection)):
    img_annotated = mask_annotator.annotate(scene=img.copy(), detections=detection[i])
    images.append(img_annotated)

sv.plot_images_grid(
    images=images,
    grid_size=(len(detection)+1, 1),

)

# %%
print(detection)
# Out:
# Detections(xyxy=array([[  0.,   2., 639., 477.],
#        [330., 154., 352., 167.],
#        [348., 228., 361., 241.]]), mask=array([[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]]), confidence=None, class_id=None, tracker_id=None, data={})

# %% [markdown]
# ## Box Prompt

# %%
pathList = randIrisPath("CASIA-Iris-Thousand",1)
for path in pathList:print(path)
image = pathList[0]
# Out:
# d:\mc\py\nectecproj\SAM-iris-nectec/images/CASIA-Iris-Thousand/779/L/S5779L05.jpg

# %%
from jupyter_bbox_widget import BBoxWidget


widget = BBoxWidget()
widget.image = encode_image(image)
widget
# Out:
# BBoxWidget(colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#b…

# %%
import numpy as np

def widgetToBox(box):
  return np.array([
    box['x'],
    box['y'],
    box['x'] + box['width'],
    box['y'] + box['height']
  ])

iris_box = widgetToBox(widget.bboxes[0])
print(iris_box)
# Out:
# [273 117 481 315]

# %% [markdown]
# SAM model does not support multiple box prompting. It supports point prompt (including points/excluding points) [Prompt Example](https://www.kaggle.com/code/danpresil1/segment-anything-model-sam-prompt-examples/notebook)
#
# ---

# %%
mask_predictor.set_image(img)

# %%
masks, scores, logits = mask_predictor.predict(
    box=iris_box, #iris
    multimask_output=False
)

# %%
import supervision as sv

def showAnnotator(masks,scores,show_mask=[0,1,2],ann_mode="bbox"):
  if ann_mode == "bbox": annotator = sv.BoundingBoxAnnotator(color=sv.Color.RED,color_lookup=sv.ColorLookup.INDEX)
  elif ann_mode == "circle": annotator = sv.CircleAnnotator(color=sv.Color.RED,color_lookup=sv.ColorLookup.INDEX)

  mask_annotator = sv.MaskAnnotator(color_lookup=sv.ColorLookup.INDEX)

  detections = sv.Detections(
      xyxy=sv.mask_to_xyxy(masks=masks),
      mask=masks
  )

  mask_img = []
  titles = []
  for i in show_mask:
    mask_img.append(annotator.annotate(scene=img.copy(), detections=detections[i]))
    mask_img.append(mask_annotator.annotate(scene=img.copy(), detections=detections[i]))
    titles.append(f'Border of Mask {i}')
    titles.append(f'Mask {i} Score={scores[i]}')
  
  sv.plot_images_grid(
    images=mask_img,
    grid_size=(len(show_mask), 2),
    titles=titles
  )

# %%
showAnnotator(masks,scores,[0])

# %% [markdown]
# ## Point Prompt

# %%
import matplotlib.pyplot as plt
import numpy as np


def pointPlot(includes:list, excludes:list, img):

  plt.imshow(img)
  for point in includes:
    plt.plot(point[0],point[1],'go')
  for point in excludes:
    plt.plot(point[0],point[1],'ro')
  plt.axis('on')
  plt.show()

  point_coords = np.array(includes+excludes)
  point_labels = np.array([1]*len(includes)+[0]*len(excludes))
  return point_coords, point_labels


def maskPredict(point_coords, point_labels, mask_predictor):
  masks, scores, logits = mask_predictor.predict(
    point_coords=point_coords,
    point_labels=point_labels,
    multimask_output=True
  )

  mask_annotator = sv.MaskAnnotator(color=sv.Color.RED, color_lookup=sv.ColorLookup.INDEX)
  detections = sv.Detections(
      xyxy=sv.mask_to_xyxy(masks=masks),
      mask=masks
  )
  mask1 = mask_annotator.annotate(scene=img.copy(), detections=detections[0])
  mask2 = mask_annotator.annotate(scene=img.copy(), detections=detections[1])
  mask3 = mask_annotator.annotate(scene=img.copy(), detections=detections[2])
  #print(detections)

  sv.plot_images_grid(
      images=[mask1, mask2, mask3],
      grid_size=(1, 3),
      titles=[
              f'Mask 1, Score={scores[0]}',
              f'Mask 2, Score={scores[1]}',
              f'Mask 3, Score={scores[2]}'
            ]
  )
  #return masks, scores, logits

# %%
includes = [[85,65],[110,50],[120,70]]
excludes = [[105,70],[60,70],[140,80]]
point_coords, point_labels = pointPlot(includes, excludes, img)
# print(point_coords,'\n')
# print(point_labels)

# %%
mask_predictor.set_image(img)

# %%
maskPredict(point_coords, point_labels,mask_predictor)

# %% [markdown]
# Box Prompt seems to have a better result than point prompt

# %% [markdown]
# # Check on n-random img

# %%
import os
from random import randint

def randIrisPath(dir:str, num:int)->list:
    base_path = f"{HOME_PATH}/images/{dir}"
    
    pathList = []
    
    for n in range(num):
        img_path = base_path
        cur_ls = os.listdir(base_path)
        while True:
            i = randint(0,len(cur_ls)-1)
            img_path+=f"/{cur_ls[i]}"
            
            if cur_ls[i].endswith('.jpg'):break
            
            cur_ls = os.listdir(img_path)
        pathList.append(img_path)
        
    return pathList

# %%
#CASIA-Iris-Distance
#CASIA-Iris-Interval
#CASIA-Iris-Lamp
#CASIA-Iris-Syn
#CASIA-Iris-Thousand
#CASIA-Iris-Twins

pathList = randIrisPath("CASIA-Iris-Thousand",4)
for path in pathList:print(path)
# Out:
# d:\mc\py\nectecproj\SAM-iris-nectec/images/CASIA-Iris-Thousand/846/L/S5846L00.jpg
# d:\mc\py\nectecproj\SAM-iris-nectec/images/CASIA-Iris-Thousand/630/R/S5630R01.jpg
# d:\mc\py\nectecproj\SAM-iris-nectec/images/CASIA-Iris-Thousand/403/L/S5403L08.jpg
# d:\mc\py\nectecproj\SAM-iris-nectec/images/CASIA-Iris-Thousand/907/L/S5907L07.jpg

# %%
import cv2
import supervision as sv

ann_images = []
titles = []

for IMAGE_PATH in pathList:
    
    img = cv2.imread(IMAGE_PATH)
    masks = mask_generator.generate(img)
    
    mask_annotator = sv.MaskAnnotator(color_lookup=sv.ColorLookup.INDEX)
    detection = sv.Detections.from_sam(sam_result=masks)
    ann = mask_annotator.annotate(scene=img.copy(), detections=detection)
    
    ann_images.append(ann)
    titles.append(IMAGE_PATH)
    
sv.plot_images_grid(
    images=ann_images,
    grid_size=(int(len(pathList)/2),2),
    titles=titles
)
